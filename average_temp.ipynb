# %%
import pandas as pd
import kaggle 
import numpy as np
import matplotlib.pyplot as pt
import seaborn as sb

# %%
! kaggle datasets download -d giabchnguyn/average-temperature-from-1900-to-2023
# Out:
# ...
#   0%|          | 0.00/681 [00:00<?, ?B/s]
# 100%|##########| 681/681 [00:00<00:00, 477kB/s]

# %%
avg_temp = pd.read_csv('Average Temperature 1900-2023.csv')

# %%
avg_temp
# Out:
#      Year  Average_Fahrenheit_Temperature
# 0    1900                            53.9
# 1    1901                            53.5
# 2    1902                            52.1
# 3    1903                            50.6
# 4    1904                            51.8
# ..    ...                             ...
# 119  2019                            53.5
# 120  2020                            53.1
# 121  2021                            54.5
# 122  2022                            54.0
# 123  2023                            53.9
#
# [124 rows x 2 columns]

# %%
# Set the style of seaborn
sb.set(style="whitegrid")

# Create a line plot
pt.figure(figsize=(20, 6))
sb.lineplot(x='Year', y='Average_Fahrenheit_Temperature', data=avg_temp, marker='o')

# Set labels and title
pt.title('Temperature over the Years')
pt.xlabel('Year')
pt.ylabel('Average_Fahrenheit_Temperature')

# Show the plot
pt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# filtering first 60 years
df_60 =  avg_temp[avg_temp['Year'] <= avg_temp['Year'].min() + 60]

# Set the style of seaborn
sb.set(style="whitegrid")

# Create a line plot
pt.figure(figsize=(20, 6))
sb.lineplot(x='Year', y='Average_Fahrenheit_Temperature', data=df_60, marker='o')

# Set labels and title
pt.title('Temperature over the Years')
pt.xlabel('Year')
pt.ylabel('Average_Fahrenheit_Temperature')

# Show the plot
pt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# filtering first 60 years
df_last =  avg_temp.tail(60)

# Set the style of seaborn
sb.set(style="whitegrid")

# Create a line plot
pt.figure(figsize=(20, 6))
sb.lineplot(x='Year', y='Average_Fahrenheit_Temperature', data=df_last, marker='o', color = 'red')

# Set labels and title
pt.title('Temperature over the Years')
pt.xlabel('Year')
pt.ylabel('Average_Fahrenheit_Temperature')

# Show the plot
pt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Convert Fahrenheit to Celsius
avg_temp['Temperature_Celsius'] = (avg_temp['Average_Fahrenheit_Temperature'] - 32) * 5/9

# Display the DataFrame with both Fahrenheit and Celsius temperatures
print(avg_temp)
# Out:
#      Year  Average_Fahrenheit_Temperature  Temperature_Celsius
# 0    1900                            53.9            12.166667
# 1    1901                            53.5            11.944444
# 2    1902                            52.1            11.166667
# 3    1903                            50.6            10.333333
# 4    1904                            51.8            11.000000
# ..    ...                             ...                  ...
# 119  2019                            53.5            11.944444
# 120  2020                            53.1            11.722222
# 121  2021                            54.5            12.500000
# 122  2022                            54.0            12.222222
# 123  2023                            53.9            12.166667
#
# [124 rows x 3 columns]

# %%
avg_temp
# Out:
#      Year  Average_Fahrenheit_Temperature  Temperature_Celsius
# 0    1900                            53.9            12.166667
# 1    1901                            53.5            11.944444
# 2    1902                            52.1            11.166667
# 3    1903                            50.6            10.333333
# 4    1904                            51.8            11.000000
# ..    ...                             ...                  ...
# 119  2019                            53.5            11.944444
# 120  2020                            53.1            11.722222
# 121  2021                            54.5            12.500000
# 122  2022                            54.0            12.222222
# 123  2023                            53.9            12.166667
#
# [124 rows x 3 columns]
